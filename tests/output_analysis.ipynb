# %%
import json

# Open and load the JSON file
with open('../places_found.json', 'r') as file:
    data = json.load(file)

# Display the JSON data
print(json.dumps(data, indent=2))
# Out:
# {
#   "date_spots": [
#     {
#       "name": "The Boardroom",
#       "description": "Classic cocktails, inventive pub fare & weekly trivia nights lure locals to this basic sports bar.",
#       "category": [
#         "Sports bar",
#         "Brunch restaurant"
#       ],
#       "price": "$10\u201320",
#       "address": "1600 Powell St, San Francisco, CA 94133",
#       "contact_information": "(415) 982-8898",
#       "reviews": 4.4,
#       "website": "",
#       "image_url": "https://lh3.googleusercontent.com/gps-proxy/ALd4DhHnQN98Woy5TXVFSXaf4I05Fpw32hgwN3pwUryOdgSOr0RgcalZgojBcuUOAHfYdw9DFzRQ-sIsa225SkxdSIRKdzFdHtoDxQswX68MdjXE-eA3x0f95bLHWiAMaCSheyRtKIF9vQLijW8pulCjijIBt1zbTqIohMUZeFzw9C3ae2vC7i8mnyZbxCukHcB02X8bf_E"
#     },
#     {
#       "name": "The Showdown",
#       "description": "Neighborhood watering hole with vintage accents & a pool table that serves American pub snacks.",
#       "category": [
#         "Bar & grill",
#         "Dive club",
# ...

# %%
len(data["date_spots"])
# Out:
# 19
